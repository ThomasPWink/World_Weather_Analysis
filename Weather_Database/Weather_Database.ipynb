# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.00, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 726

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Country": city_country,                        
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description}                         
                          )
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san cristobal
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | luanda
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | ostrovnoy
# Processing Record 12 of Set 1 | beberibe
# Processing Record 13 of Set 1 | atar
# Processing Record 14 of Set 1 | tulun
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | yerazgavors
# Processing Record 20 of Set 1 | havelock
# Processing Record 21 of Set 1 | phalodi
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | waipawa
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | araguari
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | klaksvik
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | kautokeino
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | komsomolskiy
# Processing Record 42 of Set 1 | grindavik
# Processing Record 43 of Set 1 | bulgan
# Processing Record 44 of Set 1 | cururupu
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | tete
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | anadyr
# Processing Record 3 of Set 2 | camocim
# Processing Record 4 of Set 2 | nguru
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | along
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | muros
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | nome
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | henties bay
# Processing Record 18 of Set 2 | chapais
# Processing Record 19 of Set 2 | christchurch
# Processing Record 20 of Set 2 | ust-tsilma
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | koumac
# Processing Record 24 of Set 2 | granadilla de abona
# Processing Record 25 of Set 2 | tucuman
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | colares
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | sitka
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | poshekhonye
# Processing Record 32 of Set 2 | broome
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | saint-augustin
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 2 | salta
# Processing Record 39 of Set 2 | bor
# Processing Record 40 of Set 2 | sao joao da barra
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | maiduguri
# Processing Record 44 of Set 2 | le port
# Processing Record 45 of Set 2 | adrar
# Processing Record 46 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | gainesville
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | valdepenas
# Processing Record 5 of Set 3 | san rafael
# Processing Record 6 of Set 3 | quatre cocos
# Processing Record 7 of Set 3 | galesong
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | sovetskiy
# Processing Record 10 of Set 3 | santa luzia
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | evensk
# Processing Record 14 of Set 3 | shubarshi
# Processing Record 15 of Set 3 | lipno
# Processing Record 16 of Set 3 | kruisfontein
# Processing Record 17 of Set 3 | bilibino
# Processing Record 18 of Set 3 | sorland
# Processing Record 19 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | buala
# Processing Record 22 of Set 3 | thinadhoo
# Processing Record 23 of Set 3 | bandarbeyla
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | kibre mengist
# Processing Record 26 of Set 3 | la palma
# Processing Record 27 of Set 3 | petapa
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | ambilobe
# Processing Record 31 of Set 3 | neosho
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | ambagarh chauki
# Processing Record 35 of Set 3 | vila velha
# Processing Record 36 of Set 3 | saryozek
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | yar-sale
# Processing Record 40 of Set 3 | kavieng
# Processing Record 41 of Set 3 | nishihara
# Processing Record 42 of Set 3 | tuatapere
# Processing Record 43 of Set 3 | chernyshevskiy
# Processing Record 44 of Set 3 | mananara
# Processing Record 45 of Set 3 | port hardy
# Processing Record 46 of Set 3 | tinoto
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | pavlikeni
# Processing Record 50 of Set 3 | tingi
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | san rafael del sur
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | santa cruz
# Processing Record 7 of Set 4 | yumen
# Processing Record 8 of Set 4 | goderich
# Processing Record 9 of Set 4 | rocha
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | tsaratanana
# Processing Record 14 of Set 4 | roald
# Processing Record 15 of Set 4 | pleshanovo
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | bloemfontein
# Processing Record 18 of Set 4 | pangody
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | gilbues
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | maldonado
# Processing Record 23 of Set 4 | maxixe
# Processing Record 24 of Set 4 | tutoia
# Processing Record 25 of Set 4 | clarence town
# Processing Record 26 of Set 4 | mahon
# Processing Record 27 of Set 4 | wanning
# Processing Record 28 of Set 4 | riyadh
# Processing Record 29 of Set 4 | kuching
# Processing Record 30 of Set 4 | bonthe
# Processing Record 31 of Set 4 | locri
# Processing Record 32 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 4 | takob
# City not found. Skipping...
# Processing Record 34 of Set 4 | maniitsoq
# Processing Record 35 of Set 4 | kandrian
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | adre
# Processing Record 38 of Set 4 | alice springs
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | hangu
# Processing Record 42 of Set 4 | madang
# Processing Record 43 of Set 4 | miraflores
# Processing Record 44 of Set 4 | norman wells
# Processing Record 45 of Set 4 | busselton
# Processing Record 46 of Set 4 | cayenne
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | koygorodok
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | barcelos
# Processing Record 1 of Set 5 | taoudenni
# Processing Record 2 of Set 5 | novi pazar
# Processing Record 3 of Set 5 | cabra
# Processing Record 4 of Set 5 | marystown
# Processing Record 5 of Set 5 | patacamaya
# Processing Record 6 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 7 of Set 5 | liverpool
# Processing Record 8 of Set 5 | mozarlandia
# Processing Record 9 of Set 5 | labelle
# Processing Record 10 of Set 5 | saurimo
# Processing Record 11 of Set 5 | trelleborg
# Processing Record 12 of Set 5 | vanderhoof
# Processing Record 13 of Set 5 | grand gaube
# Processing Record 14 of Set 5 | east london
# Processing Record 15 of Set 5 | salamiyah
# Processing Record 16 of Set 5 | ondangwa
# Processing Record 17 of Set 5 | mazatlan
# Processing Record 18 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 19 of Set 5 | nikolskoye
# Processing Record 20 of Set 5 | avarua
# Processing Record 21 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | tautira
# Processing Record 24 of Set 5 | lebu
# Processing Record 25 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 5 | chuy
# Processing Record 27 of Set 5 | pangnirtung
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | aklavik
# Processing Record 30 of Set 5 | la ronge
# Processing Record 31 of Set 5 | imbituba
# Processing Record 32 of Set 5 | walvis bay
# Processing Record 33 of Set 5 | vila franca do campo
# Processing Record 34 of Set 5 | broken hill
# Processing Record 35 of Set 5 | key west
# Processing Record 36 of Set 5 | takoradi
# Processing Record 37 of Set 5 | kinkala
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | marondera
# Processing Record 40 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 5 | yei
# Processing Record 42 of Set 5 | portland
# Processing Record 43 of Set 5 | lorengau
# Processing Record 44 of Set 5 | daru
# Processing Record 45 of Set 5 | ippy
# Processing Record 46 of Set 5 | alyangula
# Processing Record 47 of Set 5 | saint george
# Processing Record 48 of Set 5 | vostok
# Processing Record 49 of Set 5 | norden
# Processing Record 50 of Set 5 | mata
# Processing Record 1 of Set 6 | angoche
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | yenagoa
# Processing Record 4 of Set 6 | sarab
# Processing Record 5 of Set 6 | talakan
# Processing Record 6 of Set 6 | touros
# Processing Record 7 of Set 6 | akureyri
# Processing Record 8 of Set 6 | mercedes
# Processing Record 9 of Set 6 | meulaboh
# Processing Record 10 of Set 6 | buin
# Processing Record 11 of Set 6 | victoria
# Processing Record 12 of Set 6 | ozernovskiy
# Processing Record 13 of Set 6 | boali
# Processing Record 14 of Set 6 | aguimes
# Processing Record 15 of Set 6 | moron
# Processing Record 16 of Set 6 | lovozero
# Processing Record 17 of Set 6 | college
# Processing Record 18 of Set 6 | noumea
# Processing Record 19 of Set 6 | boca do acre
# Processing Record 20 of Set 6 | marzuq
# Processing Record 21 of Set 6 | hervey bay
# Processing Record 22 of Set 6 | aqtobe
# Processing Record 23 of Set 6 | agua dulcita
# City not found. Skipping...
# Processing Record 24 of Set 6 | serenje
# Processing Record 25 of Set 6 | hamilton
# Processing Record 26 of Set 6 | beni
# Processing Record 27 of Set 6 | porto santo
# Processing Record 28 of Set 6 | guayaramerin
# Processing Record 29 of Set 6 | puerto ayacucho
# Processing Record 30 of Set 6 | saldanha
# Processing Record 31 of Set 6 | ancud
# Processing Record 32 of Set 6 | alekseyevsk
# Processing Record 33 of Set 6 | ishigaki
# Processing Record 34 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 35 of Set 6 | vardo
# Processing Record 36 of Set 6 | flin flon
# Processing Record 37 of Set 6 | moose jaw
# Processing Record 38 of Set 6 | akom
# Processing Record 39 of Set 6 | kiruna
# Processing Record 40 of Set 6 | kitob
# Processing Record 41 of Set 6 | kenai
# Processing Record 42 of Set 6 | matara
# Processing Record 43 of Set 6 | velsk
# Processing Record 44 of Set 6 | gasa
# Processing Record 45 of Set 6 | mahebourg
# Processing Record 46 of Set 6 | simao
# Processing Record 47 of Set 6 | suhbaatar
# Processing Record 48 of Set 6 | three hills
# Processing Record 49 of Set 6 | sokolo
# Processing Record 50 of Set 6 | fortuna
# Processing Record 1 of Set 7 | anloga
# Processing Record 2 of Set 7 | tanah merah
# Processing Record 3 of Set 7 | rodrigues alves
# Processing Record 4 of Set 7 | bose
# Processing Record 5 of Set 7 | connersville
# Processing Record 6 of Set 7 | the valley
# Processing Record 7 of Set 7 | karasjok
# Processing Record 8 of Set 7 | matay
# Processing Record 9 of Set 7 | praya
# Processing Record 10 of Set 7 | general roca
# Processing Record 11 of Set 7 | shchuchye
# City not found. Skipping...
# Processing Record 12 of Set 7 | raudeberg
# Processing Record 13 of Set 7 | prince rupert
# Processing Record 14 of Set 7 | guca
# Processing Record 15 of Set 7 | karratha
# Processing Record 16 of Set 7 | hualmay
# Processing Record 17 of Set 7 | poronaysk
# Processing Record 18 of Set 7 | nouadhibou
# Processing Record 19 of Set 7 | iwanai
# Processing Record 20 of Set 7 | eureka
# Processing Record 21 of Set 7 | arlit
# Processing Record 22 of Set 7 | joue-les-tours
# Processing Record 23 of Set 7 | palu
# Processing Record 24 of Set 7 | beringovskiy
# Processing Record 25 of Set 7 | kulhudhuffushi
# Processing Record 26 of Set 7 | almaznyy
# Processing Record 27 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 7 | nguruka
# Processing Record 29 of Set 7 | loandjili
# Processing Record 30 of Set 7 | azare
# Processing Record 31 of Set 7 | blagoyevo
# Processing Record 32 of Set 7 | council bluffs
# Processing Record 33 of Set 7 | cap malheureux
# Processing Record 34 of Set 7 | alofi
# Processing Record 35 of Set 7 | mount gambier
# Processing Record 36 of Set 7 | isla mujeres
# Processing Record 37 of Set 7 | omsukchan
# Processing Record 38 of Set 7 | alta floresta
# Processing Record 39 of Set 7 | half moon bay
# Processing Record 40 of Set 7 | jalu
# Processing Record 41 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 7 | polovinnoye
# Processing Record 43 of Set 7 | awjilah
# Processing Record 44 of Set 7 | bestobe
# Processing Record 45 of Set 7 | kralendijk
# Processing Record 46 of Set 7 | bafra
# Processing Record 47 of Set 7 | oussouye
# Processing Record 48 of Set 7 | dayong
# Processing Record 49 of Set 7 | souillac
# Processing Record 50 of Set 7 | ahipara
# Processing Record 1 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 8 | san quintin
# Processing Record 3 of Set 8 | regina
# Processing Record 4 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 8 | sungaipenuh
# Processing Record 6 of Set 8 | shahe
# Processing Record 7 of Set 8 | mayo
# Processing Record 8 of Set 8 | aleksandrow kujawski
# Processing Record 9 of Set 8 | onega
# Processing Record 10 of Set 8 | margate
# Processing Record 11 of Set 8 | avera
# Processing Record 12 of Set 8 | vung tau
# Processing Record 13 of Set 8 | khani
# Processing Record 14 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 8 | areia branca
# Processing Record 16 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 8 | meadow lake
# Processing Record 18 of Set 8 | brae
# Processing Record 19 of Set 8 | porto novo
# Processing Record 20 of Set 8 | kapoeta
# Processing Record 21 of Set 8 | penalva
# Processing Record 22 of Set 8 | yangjiang
# Processing Record 23 of Set 8 | sao felix do xingu
# Processing Record 24 of Set 8 | muromtsevo
# Processing Record 25 of Set 8 | parana
# Processing Record 26 of Set 8 | praia da vitoria
# Processing Record 27 of Set 8 | sao filipe
# Processing Record 28 of Set 8 | narsaq
# Processing Record 29 of Set 8 | haines junction
# Processing Record 30 of Set 8 | lasa
# Processing Record 31 of Set 8 | buraydah
# Processing Record 32 of Set 8 | matagami
# Processing Record 33 of Set 8 | fare
# Processing Record 34 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 8 | maraba
# Processing Record 36 of Set 8 | corner brook
# Processing Record 37 of Set 8 | zalantun
# Processing Record 38 of Set 8 | laibin
# Processing Record 39 of Set 8 | matamoros
# Processing Record 40 of Set 8 | kahului
# Processing Record 41 of Set 8 | port augusta
# Processing Record 42 of Set 8 | villablino
# Processing Record 43 of Set 8 | chagoda
# Processing Record 44 of Set 8 | nacogdoches
# Processing Record 45 of Set 8 | yenotayevka
# Processing Record 46 of Set 8 | muisne
# Processing Record 47 of Set 8 | gonzalez
# Processing Record 48 of Set 8 | safaga
# Processing Record 49 of Set 8 | puke
# Processing Record 50 of Set 8 | catuday
# Processing Record 1 of Set 9 | tiznit
# Processing Record 2 of Set 9 | tazovskiy
# Processing Record 3 of Set 9 | luganville
# Processing Record 4 of Set 9 | mbanza-ngungu
# Processing Record 5 of Set 9 | anchorage
# Processing Record 6 of Set 9 | kokkola
# Processing Record 7 of Set 9 | chengmai
# City not found. Skipping...
# Processing Record 8 of Set 9 | rennes
# Processing Record 9 of Set 9 | gelnhausen
# Processing Record 10 of Set 9 | sanchor
# Processing Record 11 of Set 9 | yangambi
# Processing Record 12 of Set 9 | dutlwe
# Processing Record 13 of Set 9 | necochea
# Processing Record 14 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 15 of Set 9 | nyurba
# Processing Record 16 of Set 9 | mandeville
# Processing Record 17 of Set 9 | lyuban
# Processing Record 18 of Set 9 | agadez
# Processing Record 19 of Set 9 | berlevag
# Processing Record 20 of Set 9 | nogliki
# Processing Record 21 of Set 9 | te anau
# Processing Record 22 of Set 9 | kysyl-syr
# Processing Record 23 of Set 9 | miranda
# Processing Record 24 of Set 9 | pochutla
# Processing Record 25 of Set 9 | bilma
# Processing Record 26 of Set 9 | dudinka
# Processing Record 27 of Set 9 | jubayl
# City not found. Skipping...
# Processing Record 28 of Set 9 | camopi
# Processing Record 29 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 9 | novaya igirma
# Processing Record 31 of Set 9 | auki
# Processing Record 32 of Set 9 | darab
# Processing Record 33 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 9 | kojori
# Processing Record 35 of Set 9 | pangkalanbuun
# Processing Record 36 of Set 9 | novokizhinginsk
# Processing Record 37 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 9 | santiago del estero
# Processing Record 39 of Set 9 | sola
# Processing Record 40 of Set 9 | saint anthony
# Processing Record 41 of Set 9 | tulagi
# Processing Record 42 of Set 9 | bohodukhiv
# Processing Record 43 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 44 of Set 9 | aykhal
# Processing Record 45 of Set 9 | kurumkan
# Processing Record 46 of Set 9 | rio brilhante
# Processing Record 47 of Set 9 | orlik
# Processing Record 48 of Set 9 | gat
# Processing Record 49 of Set 9 | ixtapa
# Processing Record 50 of Set 9 | verkhnevilyuysk
# Processing Record 1 of Set 10 | makakilo city
# Processing Record 2 of Set 10 | dwarka
# Processing Record 3 of Set 10 | san juan
# Processing Record 4 of Set 10 | saint-georges
# Processing Record 5 of Set 10 | pandrup
# Processing Record 6 of Set 10 | laguna
# Processing Record 7 of Set 10 | samarai
# Processing Record 8 of Set 10 | puerto del rosario
# Processing Record 9 of Set 10 | ranong
# Processing Record 10 of Set 10 | zhigansk
# Processing Record 11 of Set 10 | sijunjung
# Processing Record 12 of Set 10 | ponta do sol
# Processing Record 13 of Set 10 | urdoma
# Processing Record 14 of Set 10 | praia
# Processing Record 15 of Set 10 | rivadavia
# Processing Record 16 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 10 | vanavara
# Processing Record 19 of Set 10 | coquimbo
# Processing Record 20 of Set 10 | bani walid
# Processing Record 21 of Set 10 | shelburne
# Processing Record 22 of Set 10 | celestun
# Processing Record 23 of Set 10 | brigantine
# Processing Record 24 of Set 10 | deniliquin
# Processing Record 25 of Set 10 | iqaluit
# Processing Record 26 of Set 10 | aktash
# Processing Record 27 of Set 10 | karpuninskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | yukamenskoye
# Processing Record 29 of Set 10 | kavaratti
# Processing Record 30 of Set 10 | duobao
# Processing Record 31 of Set 10 | tura
# Processing Record 32 of Set 10 | koslan
# Processing Record 33 of Set 10 | foshan
# Processing Record 34 of Set 10 | arroyo
# Processing Record 35 of Set 10 | jacareacanga
# Processing Record 36 of Set 10 | loikaw
# Processing Record 37 of Set 10 | cockburn town
# Processing Record 38 of Set 10 | teguise
# Processing Record 39 of Set 10 | mehamn
# Processing Record 40 of Set 10 | thunder bay
# Processing Record 41 of Set 10 | bolobo
# Processing Record 42 of Set 10 | gallup
# Processing Record 43 of Set 10 | asau
# Processing Record 44 of Set 10 | tarauaca
# Processing Record 45 of Set 10 | huarmey
# Processing Record 46 of Set 10 | jumla
# Processing Record 47 of Set 10 | tigil
# Processing Record 48 of Set 10 | poum
# Processing Record 49 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 10 | povenets
# Processing Record 1 of Set 11 | kingisepp
# Processing Record 2 of Set 11 | coihaique
# Processing Record 3 of Set 11 | musoma
# Processing Record 4 of Set 11 | buta
# Processing Record 5 of Set 11 | manggar
# Processing Record 6 of Set 11 | kousseri
# Processing Record 7 of Set 11 | bubaque
# Processing Record 8 of Set 11 | nara
# Processing Record 9 of Set 11 | zaoyang
# Processing Record 10 of Set 11 | orebro
# Processing Record 11 of Set 11 | dingle
# Processing Record 12 of Set 11 | semey
# Processing Record 13 of Set 11 | sakakah
# Processing Record 14 of Set 11 | bowen
# Processing Record 15 of Set 11 | surt
# Processing Record 16 of Set 11 | leh
# Processing Record 17 of Set 11 | presidente franco
# Processing Record 18 of Set 11 | lang son
# Processing Record 19 of Set 11 | rio gallegos
# Processing Record 20 of Set 11 | selenduma
# Processing Record 21 of Set 11 | kudahuvadhoo
# Processing Record 22 of Set 11 | san policarpo
# Processing Record 23 of Set 11 | solnechnyy
# Processing Record 24 of Set 11 | kayes
# Processing Record 25 of Set 11 | tarangnan
# Processing Record 26 of Set 11 | kendari
# Processing Record 27 of Set 11 | la libertad
# Processing Record 28 of Set 11 | sri aman
# Processing Record 29 of Set 11 | amberley
# Processing Record 30 of Set 11 | berezanka
# Processing Record 31 of Set 11 | gamba
# Processing Record 32 of Set 11 | diapaga
# Processing Record 33 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 34 of Set 11 | paita
# Processing Record 35 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 11 | carbonia
# Processing Record 37 of Set 11 | san patricio
# Processing Record 38 of Set 11 | mareeba
# Processing Record 39 of Set 11 | marsa matruh
# Processing Record 40 of Set 11 | pitimbu
# Processing Record 41 of Set 11 | olafsvik
# Processing Record 42 of Set 11 | acarau
# Processing Record 43 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 11 | springbok
# Processing Record 45 of Set 11 | haicheng
# Processing Record 46 of Set 11 | vestmannaeyjar
# Processing Record 47 of Set 11 | caceres
# Processing Record 48 of Set 11 | urumqi
# Processing Record 49 of Set 11 | bumbuna
# Processing Record 50 of Set 11 | tripoli
# Processing Record 1 of Set 12 | hami
# Processing Record 2 of Set 12 | viedma
# Processing Record 3 of Set 12 | cheremshanka
# Processing Record 4 of Set 12 | tessalit
# Processing Record 5 of Set 12 | denizli
# Processing Record 6 of Set 12 | boyle
# Processing Record 7 of Set 12 | gizo
# Processing Record 8 of Set 12 | kununurra
# Processing Record 9 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 12 | sayan
# Processing Record 11 of Set 12 | baykit
# Processing Record 12 of Set 12 | nizhnyaya tavda
# Processing Record 13 of Set 12 | lagoa
# Processing Record 14 of Set 12 | kaputa
# Processing Record 15 of Set 12 | porto walter
# Processing Record 16 of Set 12 | fort nelson
# Processing Record 17 of Set 12 | kingsland
# Processing Record 18 of Set 12 | shuangcheng
# Processing Record 19 of Set 12 | boyolangu
# Processing Record 20 of Set 12 | antalaha
# Processing Record 21 of Set 12 | kirakira
# Processing Record 22 of Set 12 | sioux lookout
# Processing Record 23 of Set 12 | bogovarovo
# Processing Record 24 of Set 12 | erdenet
# Processing Record 25 of Set 12 | fairbanks
# Processing Record 26 of Set 12 | mehendiganj
# Processing Record 27 of Set 12 | mazamari
# Processing Record 28 of Set 12 | shenjiamen
# Processing Record 29 of Set 12 | banjar
# Processing Record 30 of Set 12 | calama
# Processing Record 31 of Set 12 | hirara
# Processing Record 32 of Set 12 | arak
# Processing Record 33 of Set 12 | spornoye
# Processing Record 34 of Set 12 | sinnamary
# Processing Record 35 of Set 12 | pandan
# Processing Record 36 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 37 of Set 12 | kamaishi
# Processing Record 38 of Set 12 | maua
# Processing Record 39 of Set 12 | sao miguel do tapuio
# Processing Record 40 of Set 12 | chulym
# Processing Record 41 of Set 12 | antigonish
# Processing Record 42 of Set 12 | taunggyi
# Processing Record 43 of Set 12 | salalah
# Processing Record 44 of Set 12 | kalamakion
# City not found. Skipping...
# Processing Record 45 of Set 12 | barra velha
# Processing Record 46 of Set 12 | nongan
# Processing Record 47 of Set 12 | balkanabat
# Processing Record 48 of Set 12 | chumikan
# Processing Record 49 of Set 12 | chandrakona
# Processing Record 50 of Set 12 | wakkanai
# Processing Record 1 of Set 13 | aksu
# Processing Record 2 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 13 | comodoro rivadavia
# Processing Record 4 of Set 13 | pokosnoye
# Processing Record 5 of Set 13 | itoman
# Processing Record 6 of Set 13 | bud
# Processing Record 7 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 8 of Set 13 | eufaula
# Processing Record 9 of Set 13 | laurel
# Processing Record 10 of Set 13 | alugan
# Processing Record 11 of Set 13 | anito
# Processing Record 12 of Set 13 | ambovombe
# Processing Record 13 of Set 13 | japura
# Processing Record 14 of Set 13 | dasoguz
# Processing Record 15 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 13 | zhezkazgan
# Processing Record 17 of Set 13 | camacha
# Processing Record 18 of Set 13 | mungwi
# Processing Record 19 of Set 13 | katobu
# Processing Record 20 of Set 13 | east grinstead
# Processing Record 21 of Set 13 | palana
# Processing Record 22 of Set 13 | gayeri
# Processing Record 23 of Set 13 | ust-kuyga
# Processing Record 24 of Set 13 | hovd
# Processing Record 25 of Set 13 | acacias
# Processing Record 26 of Set 13 | naryan-mar
# Processing Record 27 of Set 13 | sisimiut
# Processing Record 28 of Set 13 | ivdel
# Processing Record 29 of Set 13 | pemangkat
# Processing Record 30 of Set 13 | paamiut
# Processing Record 31 of Set 13 | lac du bonnet
# Processing Record 32 of Set 13 | zeya
# Processing Record 33 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 13 | asha
# Processing Record 35 of Set 13 | san pedro del pinatar
# Processing Record 36 of Set 13 | gushikawa
# Processing Record 37 of Set 13 | iguatu
# Processing Record 38 of Set 13 | chiredzi
# Processing Record 39 of Set 13 | esperance
# Processing Record 40 of Set 13 | lop buri
# Processing Record 41 of Set 13 | corning
# Processing Record 42 of Set 13 | macara
# Processing Record 43 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 13 | atbasar
# Processing Record 45 of Set 13 | mormugao
# Processing Record 46 of Set 13 | manado
# Processing Record 47 of Set 13 | antofagasta
# Processing Record 48 of Set 13 | vallenar
# Processing Record 49 of Set 13 | wagga wagga
# Processing Record 50 of Set 13 | berdigestyakh
# Processing Record 1 of Set 14 | san pedro
# Processing Record 2 of Set 14 | llanes
# Processing Record 3 of Set 14 | nantucket
# Processing Record 4 of Set 14 | manikganj
# Processing Record 5 of Set 14 | sulangan
# Processing Record 6 of Set 14 | oriximina
# Processing Record 7 of Set 14 | san miguel
# Processing Record 8 of Set 14 | lavumisa
# Processing Record 9 of Set 14 | zhigalovo
# Processing Record 10 of Set 14 | bhindar
# Processing Record 11 of Set 14 | oistins
# Processing Record 12 of Set 14 | pelym
# Processing Record 13 of Set 14 | saint-francois
# Processing Record 14 of Set 14 | codrington
# Processing Record 15 of Set 14 | pohrebyshche
# Processing Record 16 of Set 14 | cartagena
# Processing Record 17 of Set 14 | calbe
# Processing Record 18 of Set 14 | ferme-neuve
# Processing Record 19 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 14 | buchmany
# Processing Record 21 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 22 of Set 14 | merrill
# Processing Record 23 of Set 14 | zhumadian
# Processing Record 24 of Set 14 | amli
# Processing Record 25 of Set 14 | diffa
# Processing Record 26 of Set 14 | bijar
# Processing Record 27 of Set 14 | mpika
# Processing Record 28 of Set 14 | mayumba
# Processing Record 29 of Set 14 | carmo do rio claro
# Processing Record 30 of Set 14 | lima
# Processing Record 31 of Set 14 | la ciotat
# Processing Record 32 of Set 14 | hobyo
# Processing Record 33 of Set 14 | corrente
# Processing Record 34 of Set 14 | ust-nera
# Processing Record 35 of Set 14 | solca
# Processing Record 36 of Set 14 | chiscas
# Processing Record 37 of Set 14 | vao
# Processing Record 38 of Set 14 | namatanai
# Processing Record 39 of Set 14 | salina
# Processing Record 40 of Set 14 | kotido
# Processing Record 41 of Set 14 | roebourne
# Processing Record 42 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 14 | mayor pablo lagerenza
# Processing Record 44 of Set 14 | las varas
# Processing Record 45 of Set 14 | mahanoro
# Processing Record 46 of Set 14 | champerico
# Processing Record 47 of Set 14 | camaqua
# Processing Record 48 of Set 14 | barinas
# Processing Record 49 of Set 14 | okhotsk
# Processing Record 50 of Set 14 | agua buena
# Processing Record 1 of Set 15 | xinxiang
# Processing Record 2 of Set 15 | palasa
# Processing Record 3 of Set 15 | maceio
# Processing Record 4 of Set 15 | port-cartier
# Processing Record 5 of Set 15 | port moresby
# Processing Record 6 of Set 15 | corinto
# Processing Record 7 of Set 15 | kargil
# Processing Record 8 of Set 15 | selestat
# Processing Record 9 of Set 15 | meybod
# Processing Record 10 of Set 15 | mezen
# Processing Record 11 of Set 15 | nuuk
# Processing Record 12 of Set 15 | vanimo
# Processing Record 13 of Set 15 | mackay
# Processing Record 14 of Set 15 | vestmanna
# Processing Record 15 of Set 15 | sorkjosen
# Processing Record 16 of Set 15 | kieta
# Processing Record 17 of Set 15 | whitehorse
# Processing Record 18 of Set 15 | nioro
# Processing Record 19 of Set 15 | san andres
# Processing Record 20 of Set 15 | lumberton
# Processing Record 21 of Set 15 | keflavik
# Processing Record 22 of Set 15 | lexington-fayette
# Processing Record 23 of Set 15 | sistranda
# Processing Record 24 of Set 15 | itarema
# Processing Record 25 of Set 15 | clyde river
# Processing Record 26 of Set 15 | sangmelima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 669

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Cristobal      VE   7.7669  -72.2250     64.58        95          72
# 1      Cape Town      ZA -33.9258   18.4232     72.37        73           5
# 2      Carnarvon      AU -24.8667  113.6333     76.37        48           0
# 3         Lompoc      US  34.6391 -120.4579     54.79        96         100
# 4         Luanda      AO  -8.8368   13.2343     78.80        89          75
# 5          Tiksi      RU  71.6872  128.8694    -29.47       100          79
# 6     Chokurdakh      RU  70.6333  147.9167    -12.82        97         100
# 7         Albany      US  42.6001  -73.9662     25.65        70           0
# 8         Hobart      AU -42.8794  147.3294     66.22        63          75
# 9      Ostrovnoy      RU  68.0531   39.5131     20.66        90         100
#
#    Wind Speed Current Description
# 0        1.07       broken clouds
# 1       10.00           clear sky
# 2       16.42           clear sky
# 3        9.22     overcast clouds
# 4        4.61       broken clouds
# 5        5.12       broken clouds
# 6        4.76     overcast clouds
# 7        1.99           clear sky
# 8        5.75       broken clouds
# 9       16.11     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Cristobal      VE   7.7669  -72.2250     64.58        95          72
# 1      Cape Town      ZA -33.9258   18.4232     72.37        73           5
# 2      Carnarvon      AU -24.8667  113.6333     76.37        48           0
# 3         Lompoc      US  34.6391 -120.4579     54.79        96         100
# 4         Luanda      AO  -8.8368   13.2343     78.80        89          75
#
#    Wind Speed Current Description
# 0        1.07       broken clouds
# 1       10.00           clear sky
# 2       16.42           clear sky
# 3        9.22     overcast clouds
# 4        4.61       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
