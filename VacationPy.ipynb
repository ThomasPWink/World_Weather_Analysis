# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd
import requests
from config import geoapify_key


# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("resources/cities.csv")
city_data_df.head()
# Out:
#    City_ID           City Country                 Date      Lat       Lng  \
# 0        0          Basco      PH  2022-12-08 23:03:06  20.4487  121.9702
# 1        1  Berdigestyakh      RU  2022-12-08 23:03:06  62.0989  126.6992
# 2        2     Bredasdorp      ZA  2022-12-08 23:03:07 -34.5322   20.0403
# 3        3        Ushuaia      AR  2022-12-08 23:00:58 -54.8000  -68.3000
# 4        4         Hobart      AU  2022-12-08 23:00:12 -42.8794  147.3294
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     78.75        81          88       19.10
# 1    -24.23        97         100        5.64
# 2     67.62        90          78        6.80
# 3     41.31        94          99        5.41
# 4     57.06        71          20       14.97

# %%
# Get the data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure the map plot_1
map_plot_1 = city_data_df.hvplot.points("Lng", "Lat", geo = True, tiles = "OSM")

# Display the map plot_1
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_2
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_3
map_plot_3 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 700,
    frame_height = 500,
    size = "Wind Speed",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Wind Speed)

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
].dropna()
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country                 Date      Lat       Lng  \
# 0         0         Basco      PH  2022-12-08 23:03:06  20.4487  121.9702
# 6         6       Maunabo      PR  2022-12-08 23:03:08  18.0072  -65.8993
# 10       10     Mahebourg      MU  2022-12-08 23:01:14 -20.4081   57.7000
# 12       12  Port Hedland      AU  2022-12-08 23:03:12 -20.3167  118.5667
# 19       19         Kapaa      US  2022-12-08 23:03:16  22.0752 -159.3190
# 26       26     Kavaratti      IN  2022-12-08 23:03:20  10.5669   72.6420
# 33       33        Atuona      PF  2022-12-08 23:03:25  -9.8000 -139.0333
# 35       35        Cairns      AU  2022-12-08 23:00:45 -16.9167  145.7667
# 38       38        Samana      DO  2022-12-08 23:03:28  19.2056  -69.3369
# 40       40       Rikitea      PF  2022-12-08 23:03:28 -23.1203 -134.9692
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      78.75        81          88       19.10
# 6      77.29        76           0        8.88
# 10     77.29        83          75       11.50
# 12     78.85        78           0       12.66
# 19     82.38        74          96        8.99
# 26     82.09        67          99       12.48
# 33     77.90        67          65       13.98
# 35     84.15        61          78        3.44
# 38     75.16        87          32        7.11
# 40     75.33        78          71       12.62

# %%
preferred_cities_df.count()
# Out:
# City_ID       132
# City          132
# Country       132
# Date          132
# Lat           132
# Lng           132
# Max Temp      132
# Humidity      132
# Cloudiness    132
# Wind Speed    132
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 0          Basco      PH     78.75  20.4487  121.9702
# 6        Maunabo      PR     77.29  18.0072  -65.8993
# 10     Mahebourg      MU     77.29 -20.4081   57.7000
# 12  Port Hedland      AU     78.85 -20.3167  118.5667
# 19         Kapaa      US     82.38  22.0752 -159.3190
# 26     Kavaratti      IN     82.09  10.5669   72.6420
# 33        Atuona      PF     77.90  -9.8000 -139.0333
# 35        Cairns      AU     84.15 -16.9167  145.7667
# 38        Samana      DO     75.16  19.2056  -69.3369
# 40       Rikitea      PF     75.33 -23.1203 -134.9692

# %%
# Set initial parameters to search for a hotel.
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
}

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"

    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

# Get the first hotel from the results and store the name

    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
    # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

# %%
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng  \
# 0          Basco      PH     78.75  20.4487  121.9702
# 6        Maunabo      PR     77.29  18.0072  -65.8993
# 10     Mahebourg      MU     77.29 -20.4081   57.7000
# 12  Port Hedland      AU     78.85 -20.3167  118.5667
# 19         Kapaa      US     82.38  22.0752 -159.3190
# 26     Kavaratti      IN     82.09  10.5669   72.6420
# 33        Atuona      PF     77.90  -9.8000 -139.0333
# 35        Cairns      AU     84.15 -16.9167  145.7667
# 38        Samana      DO     75.16  19.2056  -69.3369
# 40       Rikitea      PF     75.33 -23.1203 -134.9692
#
#                               Hotel Name
# 0                 Shanedels Inn and Cafe
# 6                         No hotel found
# 10                 Preskil Island Resort
# 12              Hospitality Port Hedland
# 19   Sheraton Kauai Coconut Beach Resort
# 26                        No hotel found
# 33                          Pearl Resort
# 35  Cairns Central Plaza Apartment Hotel
# 38           Gran Bahia Principe Cayacoa
# 40                  Chez Bianca & Benoit

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)
